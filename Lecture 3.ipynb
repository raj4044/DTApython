# %%
n=int(input("Enter a number: "))
if n>=0:
    print("positive number")
if n<0:
    print("negative number")
if n==0:
    print("zero")
# Out:
# Enter a number: 0
# positive number
# zero

# %%
n=int(input("Enter a number: "))
if n>0:
    print("positive number")
if n<0:
    print("negative number")
if n==0:
    print("zero")
# Out:
# Enter a number: -15
# negative number

# %%
pasand=input('Kon si sabji: ')
onam=['bhindi', 'loki', 'aalu']
if pasand in onam:
    print('onam likes it')
else:
    print('onam doesnt like it')
# Out:
# Kon si sabji: baigan
# onam doesnt like it

# %%
pasand=input('Kon si sabji: ')
vicky=['bhindi', 'loki', 'aalu']
if pasand in vicky:
    print('vicky likes it')
else:
    print('vicky doesnt like it')
# Out:
# Kon si sabji: loki
# vicky likes it

# %%
#program to test a year as leap year
year=int(input('Enter the year: '))
if year%400==0:
    print('yes')
elif year%4==0 and year%100!=0:
    print('yes')
else:
    print('no')

print("Checked")
# Out:
# Enter the year: 1900
# no
# Checked

# %%
#program to test a year as leap year
year=int(input('Enter the year: '))
if year%400==0:
    print('yes')
elif year%4==0 and year%100!=0:
    print('yes')
else:
    print('no')

print("Checked")
# Out:
# Enter the year: 2004
# yes
# Checked

# %%
#program to test a year as leap year
year=int(input('Enter the year: '))
if year%400==0:
    print('yes')
elif year%4==0 and year%100!=0:
    print('yes')
else:
    print('no')

print("Checked")
# Out:
# Enter the year: 2400
# yes
# Checked

# %%
#program to test a year as leap year
year=int(input('Enter the year: '))
if year%100==0:
    if year%400==0:
        print('yes')
    else:
        print('no')
elif year%4==0:
    print('yes')
else:
    print('no')

print("Checked")
# Out:
# Enter the year: 2000
# yes
# Checked

# %%
n = 5
while n>0 :    
    print(n) 
    n=n-1           #n-=1
print('Blastoff!')
print(n)
# Out:
# 5
# 4
# 3
# 2
# 1
# Blastoff!
# 0

# %%
n = 5
while n > 0 :   
    print('Lather')
    print('Rinse')
    n-=1
print('Dry off!')
# Out:
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Lather
# Rinse
# Dry off!

# %%
while True: 
    line = input('>>') 
    if line.lower()=='done' :    
        break   
    print(line)
print('Done!')
# Out:
# >>DoNe
# Done!

# %%
for i in [4, 1, 3, 2, 1]: 
     print(i)
print('Blastoff!')
# Out:
# 4
# 1
# 3
# 2
# 1
# Blastoff!

# %%
friends = ['Joseph', 'Glenn', 'Sally']
for friend in friends :    
    print('Happy New Year: ',  friend)
print('Done!')
# Out:
# Happy New Year:  Joseph
# Happy New Year:  Glenn
# Happy New Year:  Sally
# Done!

# %%
x = list(range(5))
print(x)
#[0, 1, 2, 3, 4]

x = range(3, 7)
print(x)
#[3, 4, 5, 6]

x = range(10, 1, -2)
print(x)
#[10, 8, 6, 4, 2]
# Out:
# [0, 1, 2, 3, 4]
# range(3, 7)
# range(10, 1, -2)
