# %%
num=int(input('Enter a number'))
if num%3==0 and num%5==0:
    print('Zoom')
elif num%3==0:
    print('Zip')
elif num%5==0:
    print('Zap')
else:
    print('Invalid Input')
# Out:
# Enter a number10
# Zap

# %%
num1=int(input())
num2=int(input())
num3=int(input())
if num3==7:
    product=-1
elif num2==7:
    product=1*1*num3
elif num1==7:
    product=1*num2*num3
else:
    product=num1*num2*num3

print(product)
# Out:
# 3
# 7
# 8
# 8

# %%
num1=int(input())
num2=int(input())
num3=int(input())
product=1
if num1==7:
    num1=1
elif num2==7:
    num1=1
    num2=1
elif num3==7:
    num1=1
    num2=1
    num3=(-1) 
product = num1*num2*num3 
print(product)
# Out:
# 7
# 4
# 3
# 12
