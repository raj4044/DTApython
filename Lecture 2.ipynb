# %%
str1 = 'Hello Everyone'

# %%
len(str1)
# Out:
# 14

# %%
str2 = 'Python 3.0'

# %%
len(str2)
# Out:
# 10

# %%
lst1=['H','e','l','l','o']
str3='Hello'

# %%
lst1.append([3.0])

# %%
lst1
# Out:
# ['H', 'e', 'l', 'l', 'o', [3.0]]

# %%
str3+=[3.0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-1c4546a9bdae> in <module>
# ----> 1 str3+=[3.0]
#
# TypeError: can only concatenate str (not "list") to str

# %%
str3+=str(lst1)

# %%
str3
# Out:
# "Hello['H', 'e', 'l', 'l', 'o', [3.0]]"

# %%
type(str3)
# Out:
# str

# %%
str2+='3.0'

# %%
str2
# Out:
# 'Python 3.03.0'

# %%
lst=[1,'Chandan','Sahoo']

# %%
tupl=(2, 'Sapna','Kumari')

# %%
set1={3, 'Anand', 'Kumar'}

# %%
dict1={'sl':1,'Fname':'Rajneeh',"Lname":'Kumar'}

# %%
dict1['Fname']
# Out:
# 'Rajneeh'

# %%
lst[1]
# Out:
# 'Chandan'

# %%
tupl[2]
# Out:
# 'Kumari'

# %%
set1[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-d27c0eee2e56> in <module>
# ----> 1 set1[1]
#
# TypeError: 'set' object is not subscriptable

# %%
lst.append('Lucky')

# %%
lst
# Out:
# [1, 'Chandan', 'Sahoo', 'Lucky']

# %%
tupl.append('Female')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-562071d5091a> in <module>
# ----> 1 tupl.append('Female')
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
#str vs list

# %%
str2
# Out:
# 'Python 3.03.0'

# %%
lst1
# Out:
# ['H', 'e', 'l', 'l', 'o', [3.0]]

# %%
#example[_:_:_]
str2[::]      #str2[0:-1:1]
# Out:
# 'Python 3.03.0'

# %%
lst1[2:]
# Out:
# ['l', 'l', 'o', [3.0]]

# %%
str2[:10]
# Out:
# 'Python 3.0'

# %%
str2[3:10]
# Out:
# 'hon 3.0'

# %%
str2[::3]
# Out:
# 'Ph 00'

# %%
str2[::-1]
# Out:
# '0.30.3 nohtyP'

# %%
lst
# Out:
# [1, 'Chandan', 'Sahoo', 'Lucky']

# %%
lst1
# Out:
# ['H', 'e', 'l', 'l', 'o', [3.0]]

# %%
lst2=lst+lst1

# %%
lst2
# Out:
# [1, 'Chandan', 'Sahoo', 'Lucky', 'H', 'e', 'l', 'l', 'o', [3.0]]

# %%
tupl
# Out:
# (2, 'Sapna', 'Kumari')

# %%
sl,fname,lname=tupl

# %%
sl
# Out:
# 2

# %%
lname
# Out:
# 'Kumari'

# %%
set1
# Out:
# {3, 'Anand', 'Kumar'}

# %%
set1.add('Male')

# %%
set1
# Out:
# {3, 'Anand', 'Kumar', 'Male'}

# %%
list(set1)
# Out:
# ['Anand', 'Male', 'Kumar', 3]

# %%
list(set1)
# Out:
# ['Anand', 'Male', 'Kumar', 3]

# %%
list(set1)
# Out:
# ['Anand', 'Male', 'Kumar', 3]

# %%
tuple(set1)
# Out:
# ('Anand', 'Male', 'Kumar', 3)

# %%
set1.add('Anand')

# %%
set1
# Out:
# {3, 'Anand', 'Kumar', 'Male'}

# %%
str2
# Out:
# 'Python 3.03.0'

# %%
'P' in str2
# Out:
# True

# %%
3 in set1
# Out:
# True

# %%
fname
# Out:
# 'Sapna'

# %%
fname is 'Anand'
# Out:
# False

# %%
fname is 'Sapna'
# Out:
# True

# %%
if fname=='Anand':
    print('He is Male')
else:
    print('Not male')
# Out:
# Not male
