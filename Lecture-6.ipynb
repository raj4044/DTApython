# %%
s=input()
lst=s.split(" ")
out_=("-").join(lst)
print(out_)
# Out:
# I am your Instructor.
# I-am-your-Instructor.

# %%
a=int(input())
b=int(input())
c=int(input())
res=a**b
print(res)
print(res%c)
# Out:
# 22
# 22
# 33
# 341427877364219557396646723584
# 22

# %%
num_lst=list(map(int, input().split(" ")))
for i in num_lst:
    #print(i)
    #print(str(i))
    #print(str(i)[::-1])
    if str(i)==str(i)[::-1]:
        print(i)
# Out:
# 12132 434343 6767767 82128 909090909
# 82128
# 909090909

# %%
num_lst
# Out:
# [12132, 434343, 6767767, 82128, 909090909]

# %%
lst=input().split(" ")
# Out:
# 156456 16156156 564566332 564564654

# %%
lst
# Out:
# ['156456', '16156156', '564566332', '564564654']
