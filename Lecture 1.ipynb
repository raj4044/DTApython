# %%
#lecture1
a=3
b=3

# %%
a+b
# Out:
# 6

# %%
#Brackets, of, Div, Multi, Add&sub

# %%
a*b
# Out:
# 9

# %%
a**b
# Out:
# 27

# %%
a%2
# Out:
# 1

# %%
a>2 and b>4
# Out:
# False

# %%
a>2 or b>4
# Out:
# True

# %%
a>2
# Out:
# True

# %%
b>4
# Out:
# False

# %%
# +,-,*,/,**,%, and, or, not, >, <,>=,<=,==
# =, in, is

# %%
3+4
# Out:
# 7

# %%
var3='Python Learning'

# %%
var3+a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-999fee17a02c> in <module>
# ----> 1 var3+a
#
# TypeError: can only concatenate str (not "int") to str

# %%
var3+str(a)
# Out:
# 'Python Learning3'

# %%
str(a)
# Out:
# '3'

# %%
a
# Out:
# 3

# %%
#int, float, str, list, set,tuple, frozenset

# %%
var4=20000

# %%
type(var4)
# Out:
# int

# %%
var5=20000.00

# %%
type(var5)
# Out:
# float

# %%
type(var3)
# Out:
# str

# %%
lst1=list()

# %%
type(lst1)
# Out:
# list

# %%
lst2=[3, 10.05, 'Name', [1, 2, 3]]

# %%
lst2
# Out:
# [3, 10.05, 'Name', [1, 2, 3]]

# %%
tuple1=tuple()

# %%
tuple2=(1, 'Niraj Raj', 'Patna', 'Bihar')

# %%
tuple2
# Out:
# (1, 'Niraj Raj', 'Patna', 'Bihar')

# %%
lst2[2]='Raksha Thakur'

# %%
lst2
# Out:
# [3, 10.05, 'Raksha Thakur', [1, 2, 3]]

# %%
tuple2[1]
# Out:
# 'Niraj Raj'

# %%
tuple2[1]='Niraj Kumar'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-da2f5b3b0ce2> in <module>
# ----> 1 tuple2[1]='Niraj Kumar'
#
# TypeError: 'tuple' object does not support item assignment

# %%
a1=float(input())
b1=int(input())
c1=float(a1+b1)
print(c1)
# Out:
# 10
# 20
# 30.0

# %%
a1
# Out:
# 10.0

# %%
var3+='. Welcome!!'
var3
# Out:
# 'Python Learning. Welcome!!'

# %%
var3*3
# Out:
# 'Python Learning. Welcome!!Python Learning. Welcome!!Python Learning. Welcome!!'
